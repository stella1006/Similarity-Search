# %%
import numpy as np
import pandas as pd

df = pd.read_csv('log_1.csv', header=-1)

# %%
df.tail()
# Out:
#               0        1        2        3        4        5        6   \
# 1048571  1048571   236915  1912319   670652   766022   795627    92627
# 1048572  1048572  2247465  2030932  1297403   930021  2083411   723045
# 1048573  1048573  1479539   436974    37127   478859   969470   771878
# 1048574  1048574  2096330   100130    16648   898454   697509  2302913
# 1048575  1048575   230991  1779025  1006989  2084820   488679   152903
#
#               7        8        9    ...          11       12       13  \
# 1048571   243639  1192762  2034532   ...     2213379  1778244  1270943
# 1048572  2303015  1143462   383141   ...     2182031  1070090   843686
# 1048573  1541208  1288580  2030795   ...     1666415  2324594    60984
# 1048574   767951  1442091  1864405   ...     1359223  1446183  1331257
# 1048575  1988647   518357  1912667   ...     1310734   844086   691883
#
#               14       15       16       17       18       19       20
# ...

# %%
df2 = pd.read_csv('log_2.csv', header=-1)

# %%
df2.drop(0, inplace=True)
df2.head()
# Out:
#         0        1        2        3        4        5        6        7   \
# 1  1048576  1185723  2160809   895339   636626   987577  1244527  1163066
# 2  1048577   640003   947718  2166665   533975   739166   889941  1987293
# 3  1048578  2237095  1903469   505712   723918  1602846   891537  2139515
# 4  1048579   629110  1878492   543246  1770422   402290   897639   300214
# 5  1048580     3174  1146871  1564448   687461  1644163   283866   354079
#
#         8       9    ...          11       12       13       14       15  \
# 1  2297795  784567   ...     1621664  1537181  1161991   800882  1634785
# 2  1557061  774407   ...     1830799   856144  1313925   509157  1857079
# 3  1802172  645035   ...     2135190   198504  1255222  2120035   678715
# 4  1797642    7127   ...     1643043  1866726   152903   677376  2327343
# 5   412512  467960   ...     2007892   477310   804408    97083  1870525
#
#         16       17       18       19       20
# ...

# %%
df2.tail()
# Out:
#               0        1        2        3        4        5        6   \
# 1048571  2097146  1946932   625109   492111    83873  1260549   866315
# 1048572  2097147   519776  1740195  1387573  1397055  1363874   196680
# 1048573  2097148  1532774  1310734  1895704   915192   488679  2039924
# 1048574  2097149  1060784   280824  2198920  1181420  1625557  1835041
# 1048575  2097150  2013698  1096278   468290  1679260  1224907   837198
#
#               7        8        9    ...         11       12       13  \
# 1048571  1003803   602197   522817   ...    1762259   805835   114860
# 1048572   114535   634008  2211203   ...     139055   505357  1874518
# 1048573  1310232  2085353  1943747   ...    1261537  1888982   733627
# 1048574  1790228   808526   870687   ...     883127   543369    83859
# 1048575  1051264   567701   508135   ...    1157052  2029687   725496
#
#               14       15       16       17       18       19      20
# ...

# %%
df3 = pd.read_csv('log_3.csv', header=-1)

# %%
df3.head()
# Out:
#         0        1        2        3        4        5        6        7   \
# 0  2097151  1811307  1753274   468064   993969   980544  1376954   143379
# 1  2097152  1263173  2012939  1956726   209241  2082588  2076506   175530
# 2  2097153   310559   682843   318144  2254635  1221501   720788   739791
# 3  2097154    95392  2015262  1187832  2251041  1892923    79620   861858
# 4  2097155  1957430   342235  1760678   692320  1205449  1948153  1774394
#
#         8        9    ...          11       12       13       14       15  \
# 0   183253  2301457   ...     1837859   460524   720588  1541202   960302
# 1  2003663  1097945   ...     1265108  1874119  1718737  1004716   860228
# 2  2147678  2191055   ...     1741427  1571689  1000525  1040307   337178
# 3  1298582   932561   ...     2182523  1643043  1968157  1689149    49027
# 4  1259608  1819076   ...     1661071  1801760  1881973   787226  1514780
#
#         16       17       18       19       20
# ...

# %%
frames = [df, df2, df3]
result = pd.concat(frames)

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2340373 entries, 0 to 243221
# Data columns (total 21 columns):
# 0     int64
# 1     int64
# 2     int64
# 3     int64
# 4     int64
# 5     int64
# 6     int64
# 7     int64
# 8     int64
# 9     int64
# 10    int64
# 11    int64
# 12    int64
# 13    int64
# 14    int64
# 15    int64
# 16    int64
# 17    int64
# 18    int64
# 19    int64
# 20    int64
# dtypes: int64(21)
# memory usage: 392.8 MB

# %%
result.drop(0, axis=1, inplace=True)
result.head()
# Out:
#         1        2        3        4        5        6        7        8   \
# 0  1440627  1543967  1136817  1481798  2226674  1305947  2084820   263842
# 1   567701  1654829   936183   725085   636678  1789275   329181  1931306
# 2   651879  2068245  1951416   132057   522817   444406  2264273   276218
# 3   719978  1934509  2191508   285576  1873566   976111  2055814  1723251
# 4  1442224   458512  1290084  1727083   403826  1353214  1157723  2015263
#
#         9        10       11       12       13       14       15       16  \
# 0  1483695  1866045  1857727   975382   964785    10454   504756    27043
# 1   519354   455855  1277164  1354263  1103932  1858052   130526  1597280
# 2  1680411   435789    63598   357165   226099  1628533    69609  1751494
# 3   366289  1218464   931977    73682  1054931   390278  1846559   474019
# 4  2141133   518060   552472  1605342  1636703  1997142  1049311  1930234
#
#         17       18       19       20
# ...

# %%
data = result.values

# %%
data.shape
# Out:
# (2340373, 20)

# %%
Count = [0] * 2340373
len(Count)
# Out:
# 2340373

# %%
for i in range(2340373):
    for j in range(20):
        Count[data[i][j]]+=1

# %%
Count[2]
# Out:
# 0

# %%
Count_df = pd.DataFrame(Count)

# %%
Count_df.head()
# Out:
#    Indegree
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
Count_df.rename(index=str, columns={0: "Indegree"}, inplace=True)

# %%
Count_df = Count_df[Count_df['Indegree']!=0]

# %%
Count_df
# Out:
#          Indegree
# 12              8
# 30              1
# 45              1
# 50              4
# 57              2
# 64            280
# 74             10
# 91              1
# 99             27
# 104             1
# 134            37
# 149            27
# 164             1
# 169             6
# 174             5
# 177             1
# 220          3584
# 222             1
# 225             3
# 227             2
# 228             1
# 238            53
# 247             7
# 248           174
# 250             1
# 264            18
# 267           130
# 271             1
# 280             9
# 286             1
# ...           ...
# 2340144         2
# 2340161         9
# 2340168         8
# 2340176         4
# 2340190         4
# 2340198         1
# 2340205         1
# 2340220         1
# 2340223         1
# 2340228         5
# 2340231         1
# 2340234       597
# 2340243      4790
# 2340278         1
# 2340279         7
# 2340282        48
# 2340290         1
# 2340293         1
# ...

# %%
Count_df.to_csv('nndes_indegree.csv')
